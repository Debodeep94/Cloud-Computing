# %%
import json
import boto3
import numpy as np
import PIL.Image as Image

import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import load_img

# %%
print(tf.__version__)
# Out:
# 2.9.1

# %%
best_model = keras.models.load_model('xceptionv2_119_1.000.h5')

# %%
key = 'forest-fire\\Dataset\\Dataset\\Testing\\fire\\abc001.jpg'

# %%
print(f'Image file name: {key}')
# Out:
# Image file name: forest-fire\Dataset\Dataset\Testing\fire\abc001.jpg

# %%
classes = {
    'fire_images',
    'non_fire_images'
}

# %%
image_size=(180,180)

# %%
path = 'forest-fire\\Dataset\\Dataset\\Testing\\nofire\\abc193.jpg'
img = load_img(path, target_size=(image_size))
img
# Out:
# <PIL.Image.Image image mode=RGB size=180x180 at 0x243272B2FA0>

# %%
x = np.array(img)
X = np.array([x])
X = tf.keras.applications.xception.preprocess_input(X)

# %%
preds = best_model.predict(X)
# Out:
# 1/1 [==============================] - 8s 8s/step

# %%
print('ImageName: {0}, Prediction: {1}'.format(classes, preds[0]))
# Out:
# ImageName: {'non_fire_images', 'fire_images'}, Prediction: [2.8083534e-06 9.9999714e-01]
